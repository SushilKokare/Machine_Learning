# %%
# data distribution

# %%
# 250 random floats between 0 & 5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.uniform(0.0,5,250)

# %%
# print(x)

# %%
plt.hist(x,5)
# Out:
# (array([55., 43., 49., 49., 54.]),
#  array([0.01463502, 1.00660598, 1.99857693, 2.99054788, 3.98251883,
#         4.97448978]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(x,5)
plt.show()

# %%
y=np.random.uniform(0,5,250)
plt.scatter(x,y)

# %%
# Q create an array with 100000 random numbers and display them using a histogram with 100 bars

# %%
x=np.random.uniform(0,5,100000)
plt.hist(x,100)
plt.show()
